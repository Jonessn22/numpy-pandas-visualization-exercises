# %% [markdown]
# # 1. Use matplotlib to plot the following equation: y = x^2 − x + 2
# #### You'll need to write the code that generates the x and y points.
# #### Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt

# %%
x = range(-100, 100)
y = [(x **2) - x + 2 for x in x]

# %%
plt.plot(x, y)
plt.annotate('origin', (0, 2), (-.5, 20), arrowprops = dict())
plt.show()

# %% [markdown]
# # 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %% [markdown]
# ### - y1 = √ x

# %% [markdown]
# ### - y2 = x^3

# %% [markdown]
# ### - y3 = 2^x

# %% [markdown]
# ### - y4 = 1 / (x + 1)

# %%
import math

# %% [markdown]
# # 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x = range(0, 10)

y1 = [math.sqrt(number) for number in x]
y2 = [x **3 for x in x]
y3 = [2 **x for x in x]
y4 = [1 / (x + 1) for x in x]

# %%
plt.figure(figsize = (10, 10))

plt.subplot(2, 2, 1)
plt.plot(x, y1, color = 'r')

plt.subplot(2, 2, 2)
plt.plot(x, y2, color = 'g')

plt.subplot(2, 2, 3)
plt.plot(x, y3, color = 'b')

plt.subplot(2, 2, 4)
plt.plot(x, y4, color = 'y')

# %% [markdown]
# # 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points.
# #### Be sure to include a legend and an appropriate title for the figure.

# %%
plt.plot(x, y1, color = 'r', label = 'y = √x')
plt.plot(x, y2, color = 'g', label = 'y = x^3')
plt.plot(x, y3, color = 'b', label = 'y = 2^x')
plt.plot(x, y4, color = 'y', label = 'y = 1 / (x+1)')

plt.legend()
plt.title('Combined Figure')
plt.grid(True)
plt.xlim(0, 25)
plt.ylim(-10, 100)

plt.show()
