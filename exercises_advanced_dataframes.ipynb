# %% [markdown]
# # exercises_advanced_dataframes
#
# # Part I

# %%
import pandas as pd  
import numpy as np

# %% [markdown]
# # 3. Create get_db_url function

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %% [markdown]
# # 4. Use function to obtain connection to employees database

# %%
query_emp = '''
select * from employees limit 5
'''
url_emp = get_db_url('employees')

df = pd.read_sql(query_emp, url_emp)
df
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# # 5a. Intentional database url typo

# %% [markdown]
# # 5b. Intentional SQL query error

# %% [markdown]
# # 6. Read the employees and titles tables in two separate DataFrames

# %%
query_titles = '''
select * from titles limit 5
'''

url_titles = get_db_url('employees')

df_titles = pd.read_sql(query_titles, url_titles)
df_titles
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
df_emp = pd.read_sql(query_emp, url_emp)
df_emp
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# # 7. How many rows and columns in each DataFrame?

# %%
df_emp.shape
# Out:
# (5, 6)

# %%
df_titles.shape
# Out:
# (5, 4)

# %% [markdown]
# # 8. Display summary statistics for each DataFrame

# %%
df_emp.describe()
# Out:
#              emp_no
# count      5.000000
# mean   10003.000000
# std        1.581139
# min    10001.000000
# 25%    10002.000000
# 50%    10003.000000
# 75%    10004.000000
# max    10005.000000

# %%
df_titles.describe()
# Out:
#             emp_no
# count      5.00000
# mean   10002.80000
# std        1.30384
# min    10001.00000
# 25%    10002.00000
# 50%    10003.00000
# 75%    10004.00000
# max    10004.00000

# %% [markdown]
# # 9. How many unique titles are in the titles DataFrame?

# %% [markdown]
# # 10. What is the oldest date in the to_date column?

# %% [markdown]
# # 11. What is the most recent date in the to_date column?

# %% [markdown]
# # Part II

# %% [markdown]
# # 1. Copy the users and roles DataFrames from the examples above.

# %%
#users df
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
#roles df
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# # 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, 
           left_on='role_id', 
           right_on='id',
           how='right',
          )
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# # 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, 
           left_on='role_id', 
           right_on='id',
           how='outer')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# # 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
# users_x = users.drop(columns='role_id')
# users_x

# roles_x = roles.drop(columns='id')
# roles_x

# users_x.merge(roles_x, 
#            left_on='role_id', 
#            right_on='id',
#            how='right',
#           )

# %% [markdown]
# # 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data

# %%
mpg = data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# # 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# # 7. How many rows and columns are in the dataset?

# %%
mpg.shape

#234 rows, 11 columns
# Out:
# (234, 11)

# %% [markdown]
# # 8. Check out your column names and perform any cleanup you may want on them.

# %%
#   * manufacturer. 

#   * model. 

#   * displ. engine displacement, in litres 

#   * year. 

#   * cyl. number of cylinders 

#   * trans. type of transmission 

#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd 

#   * cty. city miles per gallon 

#   * hwy. highway miles per gallon 

#   * fl. 

#   * class. 
mpg.columns = ['manufacturer', 
               'model', 
               'eng_displ', 
               'year', 
               'no_cyl', 
               'trans_type', 
               'drive_type', 
               'cty_mpg', 
               'hwy_mpg', 
               'fl', 
               'class']
mpg.head()
# Out:
#   manufacturer model  eng_displ  year  no_cyl  trans_type drive_type  cty_mpg  \
# 1         audi    a4        1.8  1999       4    auto(l5)          f       18
# 2         audi    a4        1.8  1999       4  manual(m5)          f       21
# 3         audi    a4        2.0  2008       4  manual(m6)          f       20
# 4         audi    a4        2.0  2008       4    auto(av)          f       21
# 5         audi    a4        2.8  1999       6    auto(l5)          f       16
#
#    hwy_mpg fl    class
# 1       29  p  compact
# 2       29  p  compact
# 3       31  p  compact
# 4       30  p  compact
# 5       26  p  compact

# %% [markdown]
# # 9. Display the summary statistics for the dataset.

# %%
print(mpg.describe())
print()
print(mpg.info())
# Out:
#         eng_displ         year      no_cyl     cty_mpg     hwy_mpg
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   eng_displ     234 non-null    float64
#  3   year          234 non-null    int64
#  4   no_cyl        234 non-null    int64
#  5   trans_type    234 non-null    object
#  6   drive_type    234 non-null    object
#  7   cty_mpg       234 non-null    int64
#  8   hwy_mpg       234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
# None

# %% [markdown]
# # 10. How many different manufacturers are there?

# %%
mpg.head()

print(len(mpg.groupby(by='manufacturer').count()))
print()

print(mpg.groupby(by='manufacturer').count().head())
# Out:
# 15
#
#               model  eng_displ  year  no_cyl  trans_type  drive_type  cty_mpg  \
# manufacturer
# audi             18         18    18      18          18          18       18
# chevrolet        19         19    19      19          19          19       19
# dodge            37         37    37      37          37          37       37
# ford             25         25    25      25          25          25       25
# honda             9          9     9       9           9           9        9
#
#               hwy_mpg  fl  class
# manufacturer
# audi               18  18     18
# chevrolet          19  19     19
# dodge              37  37     37
# ford               25  25     25
# honda               9   9      9

# %% [markdown]
# # 11. How many different models are there?

# %%
print(len(mpg.groupby('model').agg('count')))

print(mpg.groupby('model').agg('count').head())
# Out:
# 38
#              manufacturer  eng_displ  year  no_cyl  trans_type  drive_type  \
# model
# 4runner 4wd             6          6     6       6           6           6
# a4                      7          7     7       7           7           7
# a4 quattro              8          8     8       8           8           8
# a6 quattro              3          3     3       3           3           3
# altima                  6          6     6       6           6           6
#
#              cty_mpg  hwy_mpg  fl  class
# model
# 4runner 4wd        6        6   6      6
# a4                 7        7   7      7
# a4 quattro         8        8   8      8
# a6 quattro         3        3   3      3
# altima             6        6   6      6

# %% [markdown]
# # 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mil_diff = mpg.hwy_mpg - mpg.cty_mpg
mpg['mileage_difference'] = mil_diff

mpg.head()
# Out:
#   manufacturer model  eng_displ  year  no_cyl  trans_type drive_type  cty_mpg  \
# 1         audi    a4        1.8  1999       4    auto(l5)          f       18
# 2         audi    a4        1.8  1999       4  manual(m5)          f       21
# 3         audi    a4        2.0  2008       4  manual(m6)          f       20
# 4         audi    a4        2.0  2008       4    auto(av)          f       21
# 5         audi    a4        2.8  1999       6    auto(l5)          f       16
#
#    hwy_mpg fl    class  mileage_difference
# 1       29  p  compact                  11
# 2       29  p  compact                   8
# 3       31  p  compact                  11
# 4       30  p  compact                   9
# 5       26  p  compact                  10

# %% [markdown]
# # 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
(mpg.hwy_mpg + mpg.cty_mpg)/2
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %% [markdown]
# # 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans_type.str.startswith('auto')

mpg.head()
# Out:
#   manufacturer model  eng_displ  year  no_cyl  trans_type drive_type  cty_mpg  \
# 1         audi    a4        1.8  1999       4    auto(l5)          f       18
# 2         audi    a4        1.8  1999       4  manual(m5)          f       21
# 3         audi    a4        2.0  2008       4  manual(m6)          f       20
# 4         audi    a4        2.0  2008       4    auto(av)          f       21
# 5         audi    a4        2.8  1999       6    auto(l5)          f       16
#
#    hwy_mpg fl    class  mileage_difference  is_automatic
# 1       29  p  compact                  11          True
# 2       29  p  compact                   8         False
# 3       31  p  compact                  11         False
# 4       30  p  compact                   9          True
# 5       26  p  compact                  10          True

# %% [markdown]
# # 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg['total_mpg'] = mpg.hwy_mpg + mpg.cty_mpg

(mpg.groupby('manufacturer').agg('max').sort_values('total_mpg', ascending=False))
# Out:
#                             model  eng_displ  year  no_cyl  trans_type  \
# manufacturer
# volkswagen                 passat        3.6  2008       6  manual(m6)
# toyota          toyota tacoma 4wd        5.7  2008       8  manual(m6)
# honda                       civic        2.0  2008       4  manual(m6)
# nissan             pathfinder 4wd        5.6  2008       8  manual(m6)
# chevrolet                  malibu        7.0  2008       8  manual(m6)
# hyundai                   tiburon        3.3  2008       6  manual(m6)
# audi                   a6 quattro        4.2  2008       8  manual(m6)
# subaru                impreza awd        2.5  2008       4  manual(m5)
# pontiac                grand prix        5.3  2008       8    auto(s4)
# ford                      mustang        5.4  2008       8  manual(m6)
# dodge         ram 1500 pickup 4wd        5.9  2008       8  manual(m6)
# jeep           grand cherokee 4wd        6.1  2008       8    auto(l5)
# mercury           mountaineer 4wd        5.0  2008       8    auto(l6)
# land rover            range rover        4.6  2008       8    auto(s6)
# lincoln             navigator 2wd        5.4  2008       8    auto(l6)
#
#              drive_type  cty_mpg  hwy_mpg fl       class  mileage_difference  \
# manufacturer
# volkswagen            f       35       44  r  subcompact                  12
# toyota                f       28       37  r         suv                  10
# honda                 f       28       36  r  subcompact                  12
# nissan                f       23       32  r         suv                   9
# chevrolet             r       22       30  r         suv                  11
# hyundai               f       21       31  r  subcompact                  10
# audi                  f       21       31  p     midsize                  11
# subaru                4       21       27  r         suv                   7
# pontiac               f       18       28  r     midsize                  10
# ford                  r       18       26  r         suv                   9
# dodge                 f       18       24  r         suv                   7
# jeep                  4       17       22  r         suv                   5
# mercury               4       14       19  r         suv                   6
# land rover            4       12       18  r         suv                   6
# lincoln               r       12       18  r         suv                   6
#
#               is_automatic  total_mpg
# manufacturer
# volkswagen            True         79
# toyota                True         65
# honda                 True         61
# nissan                True         55
# chevrolet             True         52
# hyundai               True         52
# audi                  True         51
# subaru                True         47
# pontiac               True         46
# ford                  True         44
# dodge                 True         42
# jeep                  True         39
# mercury               True         32
# land rover            True         30
# lincoln               True         30

# %% [markdown]
# # 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').total_mpg.agg(['mean'])

# mpg.head()
# Out:
#                    mean
# is_automatic
# False         44.454545
# True          38.261146

# %% [markdown]
# # Part 3

# %% [markdown]
# # 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
query_chip = '''
select * from orders
'''

url_chip = get_db_url('chipotle')


df_chip = pd.read_sql(query_chip, url_chip)
df_chip.head(2)
# Out:
#    id  order_id  quantity                     item_name choice_description  \
# 0   1         1         1  Chips and Fresh Tomato Salsa                nan
# 1   2         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
df_chip['item_price'].str.replace('$', '').astype(int)
# Out:
# <ipython-input-160-cb0f574b9702>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_chip['item_price'].str.replace('$', '').astype(int)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-cb0f574b9702> in <module>
# ----> 1 df_chip['item_price'].str.replace('$', '').astype(int)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '2.39 '

# %% [markdown]
# # 2. What is the total price for each order?

# %%
df_chip.pivot_table(index='order_id', columns='id', values='item_price')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-148-ced760d1d619> in <module>
# ----> 1 df_chip.pivot_table(index='order_id', columns='id', values='item_price')
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7029         from pandas.core.reshape.pivot import pivot_table
#    7030
# -> 7031         return pivot_table(
#    7032             self,
#    7033             values=values,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     111
#     112     grouped = data.groupby(keys, observed=observed)
# --> 113     agged = grouped.agg(aggfunc)
#     114     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     115         agged = agged.dropna(how="all")
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     577
#     578     if isinstance(arg, str):
# --> 579         return obj._try_aggregate_string_function(arg, *args, **kwargs), None
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     313         if f is not None:
#     314             if callable(f):
# --> 315                 return f(*args, **kwargs)
#     316
#     317             # people may try to aggregate on a non-callable attribute
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1013         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1014     ) -> DataFrame:
# -> 1015         agg_mgr = self._cython_agg_blocks(
#    1016             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1017         )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1119
#    1120         if not len(new_mgr):
# -> 1121             raise DataError("No numeric types to aggregate")
#    1122
#    1123         return new_mgr
#
# DataError: No numeric types to aggregate

# %% [markdown]
# # 3. What are the most popular 3 items?

# %% [markdown]
# # 4. Which item has produced the most revenue?

# %% [markdown]
# # 5. Join the employees and titles DataFrames together.

# %% [markdown]
# # 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %% [markdown]
# # 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)
